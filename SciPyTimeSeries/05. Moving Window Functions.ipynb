# %%
# %matplotlib inline
import matplotlib.pylab

# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # The special thing about time series is that data points relate to one another...they are not independent
# So we can to compare them and relate them. One way to do this is to look at how they change. For example, we can 'difference' a time series

# %%
ts = pd.Series(np.random.randn(20), pd.date_range('7/1/16', freq = 'D', periods = 20))
ts_lagged = ts.shift()

# %%
plt.plot(ts, color = 'blue')
plt.plot(ts_lagged, color = 'red')

# %% [markdown]
# ### Query: how can I shift my time series 'into the future' instead of into the past?

# %%
# %load snippets/shift_future.py
ts = pd.Series(np.random.randn(20), pd.date_range('7/1/16', freq = 'D', periods = 20))
ts_lagged = ts.shift(-1)
plt.plot(ts, color = 'blue')
plt.plot(ts_lagged, color = 'red')

# %% [markdown]
# # Window functions give you moving aggregate measures of a time series

# %%
# Window functions are like aggregation functions
# You can use them in conjunction with .resample()

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('5/1/2016', freq = 'D', periods = 600), columns = ['A', 'B', 'C'])

# %%
r = df.rolling(window = 20)
r
# Out:
# Rolling [window=20,center=False,axis=0]

# %%
df['A'].plot(color = 'gray')
r.mean()['A'].plot(color = 'red')

# %% [markdown]
# ### Try out some of these options with .rolling()
#
# r.agg, r.apply, r.count, r.max, r.median, r.name, r.quantile, r.kurt,
# r.aggregate, r.std, r.skew, r.sum, r.var

# %%
r['A'].agg(['mean', 'var'])
# Out:
#                 mean       var
# 2016-05-01       NaN       NaN
# 2016-05-02       NaN       NaN
# 2016-05-03       NaN       NaN
# 2016-05-04       NaN       NaN
# 2016-05-05       NaN       NaN
# 2016-05-06       NaN       NaN
# 2016-05-07       NaN       NaN
# 2016-05-08       NaN       NaN
# 2016-05-09       NaN       NaN
# 2016-05-10       NaN       NaN
# 2016-05-11       NaN       NaN
# 2016-05-12       NaN       NaN
# 2016-05-13       NaN       NaN
# 2016-05-14       NaN       NaN
# 2016-05-15       NaN       NaN
# 2016-05-16       NaN       NaN
# 2016-05-17       NaN       NaN
# 2016-05-18       NaN       NaN
# 2016-05-19       NaN       NaN
# 2016-05-20  0.199923  1.027160
# 2016-05-21  0.192250  1.035222
# 2016-05-22  0.153377  1.023208
# 2016-05-23  0.136744  1.002643
# 2016-05-24  0.115243  1.026612
# 2016-05-25  0.048877  0.887482
# 2016-05-26  0.026904  0.849443
# 2016-05-27  0.115023  0.884598
# 2016-05-28  0.072009  0.960804
# 2016-05-29  0.059183  0.932766
# 2016-05-30  0.021800  0.828685
# ...              ...       ...
# 2017-11-22 -0.136783  1.080412
# 2017-11-23 -0.259544  0.997673
# 2017-11-24 -0.217577  1.034576
# 2017-11-25 -0.133629  0.907396
# 2017-11-26 -0.242739  0.784679
# 2017-11-27 -0.325385  0.824006
# 2017-11-28 -0.283765  0.881653
# 2017-11-29 -0.305046  0.935670
# 2017-11-30 -0.361194  0.952464
# 2017-12-01 -0.271812  1.116910
# 2017-12-02 -0.327283  0.996912
# 2017-12-03 -0.227608  0.985493
# 2017-12-04 -0.303609  0.888070
# 2017-12-05 -0.312038  0.889646
# 2017-12-06 -0.353219  0.832465
# 2017-12-07 -0.466032  0.841578
# 2017-12-08 -0.320025  0.918912
# 2017-12-09 -0.338728  0.907235
# 2017-12-10 -0.319257  0.917611
# 2017-12-11 -0.187828  0.982357
# 2017-12-12 -0.178313  0.960379
# 2017-12-13 -0.228820  1.110000
# 2017-12-14 -0.350789  1.195016
# 2017-12-15 -0.387952  1.199554
# 2017-12-16 -0.310350  1.261656
# 2017-12-17 -0.224742  1.223281
# 2017-12-18 -0.247199  1.186360
# 2017-12-19 -0.056206  1.326574
# 2017-12-20 -0.058374  1.331141
# 2017-12-21 -0.060719  1.323795
#
# [600 rows x 2 columns]

# %% [markdown]
# ### What about a custom function?

# %%
# %load snippets/custom_rolling.py
df.rolling(window = 10, center = False).apply(lambda x: x[1]/x[2])[1:10]
# Out:
#                    A         B         C
# 2016-05-02       NaN       NaN       NaN
# 2016-05-03       NaN       NaN       NaN
# 2016-05-04       NaN       NaN       NaN
# 2016-05-05       NaN       NaN       NaN
# 2016-05-06       NaN       NaN       NaN
# 2016-05-07       NaN       NaN       NaN
# 2016-05-08       NaN       NaN       NaN
# 2016-05-09       NaN       NaN       NaN
# 2016-05-10  0.788197  1.578193 -0.819711

# %% [markdown]
# ### What if I want to generate a rolling window function of monthly data from daily data?

# %%
# %load snippets/resample_rolling.py
ts_long = pd.Series(np.random.randn(200), pd.date_range('7/1/16', freq = 'D', periods = 200))
ts_long.resample('M').mean().rolling(window = 3).mean().plot()

# %% [markdown]
# ## Expanding windows

# %%
df.expanding(min_periods = 1).mean()[1:5]
# Out:
#                    A         B         C
# 2016-05-02  0.241045 -1.807091 -0.021207
# 2016-05-03  0.460259 -1.595152  0.557645
# 2016-05-04  0.298060 -1.225853  0.064672
# 2016-05-05  0.586750 -1.063695  0.123677

# %%
df.expanding(min_periods = 1).mean().plot()

# %% [markdown]
# # Try

# %% [markdown]
# (1) How can you perform an exponentially weight moving average rather than a window function? (hint: look for ewma + pandas docs)
#
# (2) When would you use an expanding window vs. a rolling window?
#
# (3) Write a custom function to repace .quantile(.5) function for a moving average
#
# (4) How would you compute more than one aggregation function on a moving window function at the same time?

# %%
# %load snippets/window_funcs_try.py
#1
ts = pd.Series(np.random.randn(1000), index = pd.date_range(start = '1/1/16', periods = 1000, freq = 'D'))
ts.ewm(span = 60, freq = 'D', min_periods = 0, adjust = True).mean().plot()
ts.rolling(window = 60).mean().plot()

#2 
# To get a more reliable statistic if it makes logical sense

#3
r = df.rolling(window = 20)
r.apply(lambda x: sorted(x)[round(len(x)*.5)])

#4
r = df.rolling(window = 20)
r.agg(['sum', 'count']).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c7878e62215e> in <module>()
#      10 #3
#      11 r = df.rolling(window = 20)
# ---> 12 r.apply(lambda x: sorted(x)[round(len(x)*.5)])
#      13
#      14 #4
#
# C:\Users\Work\Anaconda2\lib\site-packages\pandas\core\window.pyc in apply(self, func, args, kwargs)
#    1205     @Appender(_shared_docs['apply'])
#    1206     def apply(self, func, args=(), kwargs={}):
# -> 1207         return super(Rolling, self).apply(func, args=args, kwargs=kwargs)
#    1208
#    1209     @Substitution(name='rolling')
#
# C:\Users\Work\Anaconda2\lib\site-packages\pandas\core\window.pyc in apply(self, func, args, kwargs)
#     854
#     855         return self._apply(f, func, args=args, kwargs=kwargs,
# --> 856                            center=False)
#     857
#     858     def sum(self, *args, **kwargs):
#
# C:\Users\Work\Anaconda2\lib\site-packages\pandas\core\window.pyc in _apply(self, func, name, window, center, check_minp, how, **kwargs)
#     797             with np.errstate(all='ignore'):
#     798                 if values.ndim > 1:
# --> 799                     result = np.apply_along_axis(calc, self.axis, values)
#     800                 else:
#     801                     result = calc(values)
#
# C:\Users\Work\Anaconda2\lib\site-packages\numpy\lib\shape_base.pyc in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     114     except StopIteration:
#     115         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
# --> 116     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     117
#     118     # build a buffer for storing evaluations of func1d.
#
# C:\Users\Work\Anaconda2\lib\site-packages\pandas\core\window.pyc in calc(x)
#     793                 def calc(x):
#     794                     return func(x, window, min_periods=self.min_periods,
# --> 795                                 closed=self.closed)
#     796
#     797             with np.errstate(all='ignore'):
#
# C:\Users\Work\Anaconda2\lib\site-packages\pandas\core\window.pyc in f(arg, window, min_periods, closed)
#     851             minp = _use_window(min_periods, window)
#     852             return _window.roll_generic(arg, window, minp, indexi, closed,
# --> 853                                         offset, func, args, kwargs)
#     854
#     855         return self._apply(f, func, args=args, kwargs=kwargs,
#
# pandas\_libs\window.pyx in pandas._libs.window.roll_generic (pandas\_libs\window.c:36061)()
#
# <ipython-input-41-c7878e62215e> in <lambda>(x)
#      10 #3
#      11 r = df.rolling(window = 20)
# ---> 12 r.apply(lambda x: sorted(x)[round(len(x)*.5)])
#      13
#      14 #4
#
# TypeError: list indices must be integers, not float

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range(start = '1/1/16', periods = 1000, freq = 'D'))

# %%
ts.ewm(span = 60, freq = 'D', min_periods = 0, adjust = True).mean().plot()
ts.rolling(window = 30).mean().plot()

# %%
#3 function to compute rolling median of a series

def median_func(series, window_size):
    med = series.rolling(window=window_size).apply(lambda x: np.sort(x)[int(round(len(x)*0.5))])
    return med

# %%
median_func(df['A'], 20)
# Out:
# 2016-05-01         NaN
# 2016-05-02         NaN
# 2016-05-03         NaN
# 2016-05-04         NaN
# 2016-05-05         NaN
# 2016-05-06         NaN
# 2016-05-07         NaN
# 2016-05-08         NaN
# 2016-05-09         NaN
# 2016-05-10         NaN
# 2016-05-11         NaN
# 2016-05-12         NaN
# 2016-05-13         NaN
# 2016-05-14         NaN
# 2016-05-15         NaN
# 2016-05-16         NaN
# 2016-05-17         NaN
# 2016-05-18         NaN
# 2016-05-19         NaN
# 2016-05-20    0.384725
# 2016-05-21    0.384725
# 2016-05-22   -0.023077
# 2016-05-23   -0.023077
# 2016-05-24   -0.023077
# 2016-05-25   -0.023077
# 2016-05-26   -0.023077
# 2016-05-27    0.384725
# 2016-05-28    0.384725
# 2016-05-29    0.384725
# 2016-05-30    0.384725
#                 ...
# 2017-11-22   -0.062852
# 2017-11-23   -0.240542
# 2017-11-24   -0.062852
# 2017-11-25   -0.055734
# 2017-11-26   -0.062852
# 2017-11-27   -0.270594
# 2017-11-28   -0.270594
# 2017-11-29   -0.270594
# 2017-11-30   -0.312381
# 2017-12-01   -0.270594
# 2017-12-02   -0.270594
# 2017-12-03   -0.055734
# 2017-12-04   -0.270594
# 2017-12-05   -0.270594
# 2017-12-06   -0.270594
# 2017-12-07   -0.416731
# 2017-12-08   -0.270594
# 2017-12-09   -0.270594
# 2017-12-10   -0.219866
# 2017-12-11   -0.084878
# 2017-12-12   -0.084878
# 2017-12-13   -0.084878
# 2017-12-14   -0.219866
# 2017-12-15   -0.416731
# 2017-12-16   -0.219866
# 2017-12-17   -0.084878
# 2017-12-18   -0.084878
# 2017-12-19    0.118828
# 2017-12-20    0.118828
# 2017-12-21    0.118828
# Freq: D, Name: A, Length: 600, dtype: float64

# %%
df['A'].rolling(window = 20).agg(['mean', 'var'])
# Out:
#                 mean       var
# 2016-05-01       NaN       NaN
# 2016-05-02       NaN       NaN
# 2016-05-03       NaN       NaN
# 2016-05-04       NaN       NaN
# 2016-05-05       NaN       NaN
# 2016-05-06       NaN       NaN
# 2016-05-07       NaN       NaN
# 2016-05-08       NaN       NaN
# 2016-05-09       NaN       NaN
# 2016-05-10       NaN       NaN
# 2016-05-11       NaN       NaN
# 2016-05-12       NaN       NaN
# 2016-05-13       NaN       NaN
# 2016-05-14       NaN       NaN
# 2016-05-15       NaN       NaN
# 2016-05-16       NaN       NaN
# 2016-05-17       NaN       NaN
# 2016-05-18       NaN       NaN
# 2016-05-19       NaN       NaN
# 2016-05-20  0.199923  1.027160
# 2016-05-21  0.192250  1.035222
# 2016-05-22  0.153377  1.023208
# 2016-05-23  0.136744  1.002643
# 2016-05-24  0.115243  1.026612
# 2016-05-25  0.048877  0.887482
# 2016-05-26  0.026904  0.849443
# 2016-05-27  0.115023  0.884598
# 2016-05-28  0.072009  0.960804
# 2016-05-29  0.059183  0.932766
# 2016-05-30  0.021800  0.828685
# ...              ...       ...
# 2017-11-22 -0.136783  1.080412
# 2017-11-23 -0.259544  0.997673
# 2017-11-24 -0.217577  1.034576
# 2017-11-25 -0.133629  0.907396
# 2017-11-26 -0.242739  0.784679
# 2017-11-27 -0.325385  0.824006
# 2017-11-28 -0.283765  0.881653
# 2017-11-29 -0.305046  0.935670
# 2017-11-30 -0.361194  0.952464
# 2017-12-01 -0.271812  1.116910
# 2017-12-02 -0.327283  0.996912
# 2017-12-03 -0.227608  0.985493
# 2017-12-04 -0.303609  0.888070
# 2017-12-05 -0.312038  0.889646
# 2017-12-06 -0.353219  0.832465
# 2017-12-07 -0.466032  0.841578
# 2017-12-08 -0.320025  0.918912
# 2017-12-09 -0.338728  0.907235
# 2017-12-10 -0.319257  0.917611
# 2017-12-11 -0.187828  0.982357
# 2017-12-12 -0.178313  0.960379
# 2017-12-13 -0.228820  1.110000
# 2017-12-14 -0.350789  1.195016
# 2017-12-15 -0.387952  1.199554
# 2017-12-16 -0.310350  1.261656
# 2017-12-17 -0.224742  1.223281
# 2017-12-18 -0.247199  1.186360
# 2017-12-19 -0.056206  1.326574
# 2017-12-20 -0.058374  1.331141
# 2017-12-21 -0.060719  1.323795
#
# [600 rows x 2 columns]
